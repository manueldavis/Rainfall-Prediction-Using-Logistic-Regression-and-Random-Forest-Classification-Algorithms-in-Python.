# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('weatherAUS.csv') #reading the dataset

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
df.shape #identifying the number of rows and columns(features)
# Out:
# (145460, 23)

# %%
df.head() #viewing the first five records
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.tail() #viewing the last five rows of the dataset
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 145455       NaN           E           31.0         SE  ...        51.0
# 145456       NaN         NNW           22.0         SE  ...        56.0
# 145457       NaN           N           37.0         SE  ...        53.0
# 145458       NaN          SE           28.0        SSE  ...        51.0
# 145459       NaN         NaN            NaN        ESE  ...        62.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
df.isnull().any()
# Out:
# Date             False
# Location         False
# MinTemp           True
# MaxTemp           True
# Rainfall          True
# Evaporation       True
# Sunshine          True
# WindGustDir       True
# WindGustSpeed     True
# WindDir9am        True
# WindDir3pm        True
# WindSpeed9am      True
# WindSpeed3pm      True
# Humidity9am       True
# Humidity3pm       True
# Pressure9am       True
# Pressure3pm       True
# Cloud9am          True
# Cloud3pm          True
# Temp9am           True
# Temp3pm           True
# RainToday         True
# RainTomorrow      True
# dtype: bool

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (56420, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56420 entries, 6049 to 142302
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           56420 non-null  object
#  1   Location       56420 non-null  object
#  2   MinTemp        56420 non-null  float64
#  3   MaxTemp        56420 non-null  float64
#  4   Rainfall       56420 non-null  float64
#  5   Evaporation    56420 non-null  float64
#  6   Sunshine       56420 non-null  float64
#  7   WindGustDir    56420 non-null  object
#  8   WindGustSpeed  56420 non-null  float64
#  9   WindDir9am     56420 non-null  object
#  10  WindDir3pm     56420 non-null  object
#  11  WindSpeed9am   56420 non-null  float64
#  12  WindSpeed3pm   56420 non-null  float64
#  13  Humidity9am    56420 non-null  float64
#  14  Humidity3pm    56420 non-null  float64
#  15  Pressure9am    56420 non-null  float64
#  16  Pressure3pm    56420 non-null  float64
# ...

# %%
df = df.drop(columns=['Date','Location','WindGustDir', 'WindDir9am', 'WindDir3pm', 'Evaporation', 'Sunshine'], axis=1) #dropping irrelevant features

# %%
df.shape
# Out:
# (56420, 16)

# %%
df.head()
# Out:
#       MinTemp  MaxTemp  Rainfall  WindGustSpeed  WindSpeed9am  WindSpeed3pm  \
# 6049     17.9     35.2       0.0           48.0           6.0          20.0
# 6050     18.4     28.9       0.0           37.0          19.0          19.0
# 6052     19.4     37.6       0.0           46.0          30.0          15.0
# 6053     21.9     38.4       0.0           31.0           6.0           6.0
# 6054     24.2     41.0       0.0           35.0          17.0          13.0
#
#       Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# 6049         20.0         13.0       1006.3       1004.4       2.0       5.0
# 6050         30.0          8.0       1012.9       1012.1       1.0       1.0
# 6052         42.0         22.0       1012.3       1009.2       1.0       6.0
# 6053         37.0         22.0       1012.7       1009.1       1.0       5.0
# 6054         19.0         15.0       1010.7       1007.4       1.0       6.0
#
#       Temp9am  Temp3pm RainToday RainTomorrow
# ...

# %%
df['RainToday'] = df['RainToday'].replace(['No','Yes'], [0,1])

# %%
df['RainTomorrow'] = df['RainTomorrow'].replace(['No','Yes'], [0,1])

# %%
df.head(100)
# Out:
#       MinTemp  MaxTemp  Rainfall  WindGustSpeed  WindSpeed9am  WindSpeed3pm  \
# 6049     17.9     35.2       0.0           48.0           6.0          20.0
# 6050     18.4     28.9       0.0           37.0          19.0          19.0
# 6052     19.4     37.6       0.0           46.0          30.0          15.0
# 6053     21.9     38.4       0.0           31.0           6.0           6.0
# 6054     24.2     41.0       0.0           35.0          17.0          13.0
# ...       ...      ...       ...            ...           ...           ...
# 6147     17.1     28.7       0.0           43.0          15.0          15.0
# 6148     16.5     20.6      14.4           30.0           7.0           9.0
# 6149     16.0     24.4       2.4           31.0           4.0          15.0
# 6150     16.8     23.9       5.4           20.0           4.0           7.0
# 6151     16.2     23.9       0.0           24.0           6.0           9.0
#
# ...

# %%
plt.subplots(figsize=(15,8))
 
for i, col in enumerate(df):
  plt.subplot(4,4, i + 1)
  sns.distplot(df[col])
plt.tight_layout()
plt.show()

# %%
plt.pie(df['RainTomorrow'].value_counts().values,
        labels = df['RainTomorrow'].value_counts().index,
        autopct='%1.1f%%')
plt.show()

# %%
from sklearn import preprocessing

# %%
scaler = preprocessing.MinMaxScaler() #data normalization or scaling

scaler.fit(df)

df = pd.DataFrame(scaler.transform(df), index=df.index, columns=df.columns)

# %%
df.head(50)
# Out:
#        MinTemp   MaxTemp  Rainfall  WindGustSpeed  WindSpeed9am  WindSpeed3pm  \
# 6049  0.645669  0.706818  0.000000       0.339130      0.061538      0.243243
# 6050  0.658793  0.563636  0.000000       0.243478      0.261538      0.229730
# 6052  0.685039  0.761364  0.000000       0.321739      0.430769      0.175676
# 6053  0.750656  0.779545  0.000000       0.191304      0.061538      0.054054
# 6054  0.811024  0.838636  0.000000       0.226087      0.230769      0.148649
# 6055  0.887139  0.727273  0.000000       0.295652      0.076923      0.243243
# 6056  0.787402  0.679545  0.000000       0.278261      0.230769      0.229730
# 6057  0.598425  0.684091  0.000000       0.243478      0.200000      0.054054
# 6058  0.674541  0.713636  0.000000       0.339130      0.430769      0.094595
# 6059  0.692913  0.713636  0.000000       0.278261      0.200000      0.202703
# 6060  0.724409  0.765909  0.000000       0.182609      0.138462      0.067568
# ...

# %%
from sklearn.feature_selection import SelectKBest, chi2

# %%
x = df.loc[:,df.columns != 'RainTomorrow'] #selecting all features except the target RainTomorrow as x
y = df['RainTomorrow'] #setting the target variable RainTomorrow as y
selector = SelectKBest(chi2, k=8) #instantiating the SelectKBest method to select the best ten features
selector.fit(x,y) #fitting the x, y to SelectKBest instance
x_new = selector.transform(x)

# %%
x.columns[selector.get_support(indices=True)]
# Out:
# Index(['Rainfall', 'WindGustSpeed', 'Humidity9am', 'Humidity3pm', 'Cloud9am',
#        'Cloud3pm', 'Temp3pm', 'RainToday'],
#       dtype='object')

# %%
x = df[['Rainfall', 'WindGustSpeed', 'Humidity9am', 'Humidity3pm', 'Cloud9am', 'Cloud3pm', 'Temp3pm', 'RainToday' ]]
y = df['RainTomorrow']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)
clf_logreg = LogisticRegression(random_state=0)

# %%
clf_logreg.fit(x_train, y_train.values.ravel())
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred = clf_logreg.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
cf_matrix = confusion_matrix(y_test, y_pred)

# %%
cf_matrix
# Out:
# array([[10352,   588],
#        [ 1592,  1573]], dtype=int64)

# %%
import seaborn as sns

# %%
sns.heatmap(cf_matrix/np.sum(cf_matrix), annot=True, 
            fmt='.2%', cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
l_score = accuracy_score(y_test, y_pred)

# %%
l_score*100
# Out:
# 84.54448777029423

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
mod2 = RandomForestClassifier()

# %%
mod2.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred2 = mod2.predict(x_test)

# %%
rf_score = accuracy_score(y_test, y_pred2 )

# %%
rf_score*100
# Out:
# 84.57284650833039

# %%
cf_matrix2 = confusion_matrix(y_test, y_pred2)

# %%
cf_matrix2
# Out:
# array([[10388,   552],
#        [ 1624,  1541]], dtype=int64)

# %%
sns.heatmap(cf_matrix2/np.sum(cf_matrix2), annot=True, 
            fmt='.2%', cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
#Seaborn bar plot
models = ['Logistic Regression', 'Random Forest']
accuracies = [l_score, rf_score]

sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))
ax = sns.barplot(x=models, y=accuracies, palette="viridis")
plt.title('Accuracy Scores: Logistic Regression vs Random Forest')
plt.ylabel('Accuracy')
plt.ylim(0.0, 1.0)
# Out:
# (0.0, 1.0)
